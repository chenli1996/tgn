# %%
import torch

# %%
# !pip install torch

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Wed Mar 27 17:11:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.154.05             Driver Version: 535.154.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-32GB           On  | 00000000:3B:00.0 Off |                    0 |
# | N/A   30C    P0              39W / 300W |      3MiB / 32768MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install numpy
# !top

# %%
import numpy

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------
# addict                    2.4.0
# archspec                  0.2.1
# asttokens                 2.0.5
# attrs                     23.2.0
# backcall                  0.2.0
# blinker                   1.7.0
# boltons                   23.0.0
# Brotli                    1.0.9
# certifi                   2023.11.17
# cffi                      1.15.1
# charset-normalizer        2.0.4
# click                     8.1.7
# comm                      0.2.1
# conda                     23.11.0
# conda-content-trust       0.2.0
# conda-libmamba-solver     23.11.1
# conda-package-handling    2.2.0
# conda_package_streaming   0.9.0
# ConfigArgParse            1.7
# contourpy                 1.2.0
# cryptography              41.0.3
# cycler                    0.12.1
# dash                      2.15.0
# dash-core-components      2.0.0
# dash-html-components      2.0.0
# dash-table                5.0.0
# ...

# %%
# !pip install pandas
# !pip install open3d
# Out:
# ...
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 21.1 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.7/399.7 MB 19.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 73.7 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 78.6 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 24.6 MB/s eta 0:00:00:00:01
# ...

# %%
import open3d as o3d

# # Load the point cloud data
point_cloud = o3d.io.read_point_cloud("./longdress_vox10_1097.ply")

# # Visualize the point cloud
# o3d.visualization.draw_geometries([point_cloud])

# def custom_draw_geometry(pcd):
#     # The following code achieves the same effect as:
#     # o3d.visualization.draw_geometries([pcd])
#     vis = o3d.visualization.Visualizer()
#     vis.create_window()
#     vis.add_geometry(pcd)
#     vis.run()
#     vis.destroy_window()
    
# custom_draw_geometry(point_cloud)

# def custom_draw_geometry_load_option(pcd):
#     vis = o3d.visualization.Visualizer()
#     vis.create_window()
#     vis.add_geometry(pcd)
#     vis.get_render_option().load_from_json("./tile_data/open3d_test_results/camera_params.json")
#     vis.run()
#     vis.destroy_window()
    
# custom_draw_geometry_load_option(point_cloud)    



def custom_draw_geometry_with_custom_fov(pcd, fov_step):
    vis = o3d.visualization.Visualizer()
    vis.create_window()
    vis.add_geometry(pcd)
#     ctr = vis.get_view_control()
#     print("Field of view (before changing) %.2f" % ctr.get_field_of_view())
#     ctr.change_field_of_view(step=fov_step)
    print(fov_step)
#     print("Field of view (after changing) %.2f" % ctr.get_field_of_view())
    vis.run()
    vis.destroy_window()
    
custom_draw_geometry_with_custom_fov(point_cloud, -20)

# def custom_draw_geometry_with_rotation(point_cloud):

#     def rotate_view(vis):
#         ctr = vis.get_view_control()
#         ctr.rotate(10.0, 0.0)
#         return False

#     o3d.visualization.draw_geometries_with_animation_callback([point_cloud],
#                                                               rotate_view)

# custom_draw_geometry_with_rotation(point_cloud)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import open3d as o3d
#       3 # # Load the point cloud data
#       4 point_cloud = o3d.io.read_point_cloud("./longdress_vox10_1097.ply")
#
# File ~/tgn/open3d.py:4
#       1 import open3d as o3d
#       3 # # Load the point cloud data
# ----> 4 point_cloud = o3d.io.read_point_cloud("./longdress_vox10_1097.ply")
#       6 # # Visualize the point cloud
#       7 # o3d.visualization.draw_geometries([point_cloud])
#       8
#    (...)
#      27
#      28 # custom_draw_geometry_load_option(point_cloud)
#      32 def custom_draw_geometry_with_custom_fov(pcd, fov_step):
#
# AttributeError: partially initialized module 'open3d' has no attribute 'io' (most likely due to a circular import)

# %%
# !python open3d_chen.py
# Out:
# -20

# %%
# !python train_self_supervised.py --use_memory --prefix tgn-attn --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=2048, prefix='tgn-attn', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# (157475, 172) edge (9228, 172) node
# 157474
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 110232 interactions, involving 7475 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 5307 interactions, involving 1251 different nodes
# ...

# %%
# !pip install scikit-learn

# %%
# !python train_supervised.py --use_memory --prefix tgn-attn --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=100, prefix='tgn-attn', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0003, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, n_neg=1, use_validation=False, new_node=False)
# DEBUG:root:Num of training instances: 133853
# DEBUG:root:Num of batches per epoch: 1339
# INFO:root:Loading saved TGN model
# INFO:root:TGN models loaded
# INFO:root:Start training node classification task
# INFO:root:Epoch 0: train loss: 0.044116805916574006, val auc: 0.8745527227999552, time: 45.44306492805481
# INFO:root:Epoch 1: train loss: 0.010263678699359628, val auc: 0.8619152139797261, time: 44.68082356452942
# ...

# %% [markdown]
# # e2e with ng sampling

# %%
# !python train_self_supervised_e2e.py --use_memory --prefix tgn-attn-e2eng --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn-e2eng', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...

# %%
# !python train_self_supervised_e2e.py --use_memory --prefix tgn-attn-e2eng --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn-e2eng', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...

# %% [markdown]
# # e2e without ng sampling

# %%
# !python train_self_supervised_e2e.py --use_memory --prefix tgn-attn-e2eng --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn-e2eng', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...

# %%
# !python train_self_supervised_e2e.py --use_memory --prefix tgn-attn-e2eng --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn-e2eng', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...

# %% [markdown]
# # edge value predict node

# %%
# !python train_self_supervised_e2e.py --use_memory --prefix tgn-attn-e2eng --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn-e2eng', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...

# %% [markdown]
# # edge value predict node ng smpl

# %%
# !python train_self_supervised_e2e.py --use_memory --prefix tgn-attn-e2eng --n_runs 1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='wikipedia', bs=200, prefix='tgn-attn-e2eng', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0001, patience=5, n_runs=1, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# The dataset has 157474 interactions, involving 9227 different nodes
# The training dataset has 79202 interactions, involving 5904 different nodes
# The validation dataset has 23621 interactions, involving 3256 different nodes
# The test dataset has 23621 interactions, involving 3564 different nodes
# The new node validation dataset has 11742 interactions, involving 2134 different nodes
# ...

# %% [markdown]
# # wikipidia test

# %%
# !python train_self_supervised.py --use_memory --prefix tgn-attn --n_runs 10 --data wikipedia &> out.txt

# %% [markdown]
# # longdresstgn_u1

# %%
# !python train_self_supervised.py --use_memory --prefix tgn-attn5s --n_runs 3 --data longdresstgn_u1
# Out:
# INFO:root:Namespace(data='longdresstgn_u1', bs=2048, prefix='tgn-attn5s', n_degree=10, n_head=2, n_epoch=50, n_layer=1, lr=0.0001, patience=5, n_runs=3, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', memory_updater='gru', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, dyrep=False)
# (30003, 172) edge (2769, 172) node
# 425708
# The dataset has 425708 interactions, involving 482 different nodes
# The training dataset has 300588 interactions, involving 449 different nodes
# The validation dataset has 62714 interactions, involving 331 different nodes
# The test dataset has 62406 interactions, involving 283 different nodes
# ...

# %%
#first user 5s

# %%
# !python train_supervised.py --use_memory --prefix tgn-attn5s --n_runs 3 --data longdresstgn_u1 --n_epoch 10
# Out:
# INFO:root:Namespace(data='longdresstgn_u1', bs=256, prefix='tgn-attn5s', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.003, patience=5, n_runs=3, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, n_neg=1, use_validation=False, new_node=False)
# DEBUG:root:Num of training instances: 363302
# DEBUG:root:Num of batches per epoch: 1420
# INFO:root:Loading saved TGN model
# INFO:root:TGN models loaded
# INFO:root:Start training node classification task
# INFO:root:Epoch 0: train loss: 0.12417470520283555, val auc: 0, time: 30.725358486175537
# INFO:root:Epoch 1: train loss: 0.12247366709241145, val auc: 0, time: 29.859827995300293
# ...

# %%
# !python train_supervised.py --use_memory --prefix tgn-attn --n_runs 10 --data longdresstgn --n_epoch 10
# Out:
# INFO:root:Namespace(data='longdresstgn', bs=1024, prefix='tgn-attn', n_degree=10, n_head=2, n_epoch=10, n_layer=1, lr=0.0003, patience=5, n_runs=10, drop_out=0.1, gpu=0, node_dim=100, time_dim=100, backprop_every=1, use_memory=True, embedding_module='graph_attention', message_function='identity', aggregator='last', memory_update_at_end=False, message_dim=100, memory_dim=172, different_new_nodes=False, uniform=False, randomize_features=False, use_destination_embedding_in_message=False, use_source_embedding_in_message=False, n_neg=1, use_validation=False, new_node=False)
# DEBUG:root:Num of training instances: 256452
# DEBUG:root:Num of batches per epoch: 251
# INFO:root:Loading saved TGN model
# INFO:root:TGN models loaded
# INFO:root:Start training node classification task
# INFO:root:Epoch 0: train loss: 1.4297710172683595, val auc: 0, time: 18.710742473602295
# INFO:root:Epoch 1: train loss: 1.3898361783578577, val auc: 0, time: 17.198753833770752
# ...
